# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import scipy
import seaborn as sns

# %%
data = pd.read_csv('beach_water_quality_automated_sensors_1.csv')
data.head()
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28T12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0             0.891        0.080          3.0           9.4
# 1               NaN        0.111          4.0          12.4
# 2             1.201        0.174          6.0           9.4
# 3             1.514        0.147          4.0          11.7
# 4             1.388        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id
# 0         2013-08-30T08:00:00    MontroseBeach201308300800
# ...

# %%
data.count()
# Out:
# beach_name                     34923
# measurement_timestamp          34917
# water_temperature              34917
# turbidity                      34917
# transducer_depth               10034
# wave_height                    34690
# wave_period                    34690
# battery_life                   34917
# measurement_timestamp_label    34917
# measurement_id                 34923
# dtype: int64

# %%
data.isnull().sum()
# Out:
# beach_name                         0
# measurement_timestamp              6
# water_temperature                  6
# turbidity                          6
# transducer_depth               24889
# wave_height                      233
# wave_period                      233
# battery_life                       6
# measurement_timestamp_label        6
# measurement_id                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34923 entries, 0 to 34922
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   beach_name                   34923 non-null  object
#  1   measurement_timestamp        34917 non-null  object
#  2   water_temperature            34917 non-null  float64
#  3   turbidity                    34917 non-null  float64
#  4   transducer_depth             10034 non-null  float64
#  5   wave_height                  34690 non-null  float64
#  6   wave_period                  34690 non-null  float64
#  7   battery_life                 34917 non-null  float64
#  8   measurement_timestamp_label  34917 non-null  object
#  9   measurement_id               34923 non-null  object
# dtypes: float64(6), object(4)
# memory usage: 2.7+ MB

# %%
#calcular estadistica descriptiva de los datos, cual es promedio,desviacion estandar std,min-max ,quarteil 
data.describe()
# Out:
#        water_temperature     turbidity  transducer_depth   wave_height  \
# count       34917.000000  34917.000000      10034.000000  34690.000000
# mean           19.363387      4.823575          1.570235  -1516.116166
# std             3.356908     33.506600          0.175118  12220.244835
# min             0.000000      0.000000         -0.082000 -99999.992000
# 25%            17.100000      0.660000          1.426000      0.110000
# 50%            19.600000      1.260000          1.578000      0.154000
# 75%            22.000000      2.540000          1.721000      0.201000
# max            31.500000   1683.480000          2.214000      1.467000
#
#          wave_period  battery_life
# count   34690.000000  34917.000000
# mean    -1512.482041     11.038205
# std     12220.696864      0.771769
# min   -100000.000000      4.800000
# 25%         3.000000     10.600000
# 50%         3.000000     11.000000
# 75%         4.000000     11.500000
# max        10.000000     13.300000

# %%
#renombrar algunos campos
data.rename(columns={'beach_name': 'name','water_temperature':'temp','measurement_timestamp_label':'timestamp'},inplace=true)

data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-193c4ad6a63e> in <module>
#       1 #renombrar algunos campos
# ----> 2 data.rename(columns={'beach_name': 'name','water_temperature':'temp','measurement_timestamp_label':'timestamp'},inplace=true)
#       3
#       4 data.head()
#
# NameError: name 'true' is not defined

# %%
#accder a nombres
data.loc[10:19,'name':'turbidity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\entornomp1\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-687c2946a5d3> in <module>
#       1 #accder a nombres
# ...

# %%
data.iloc[10:19,:]#acceder a indice
# Out:
#         beach_name measurement_timestamp  water_temperature  turbidity  \
# 10  Montrose Beach   2014-05-28T15:00:00               14.5       4.30
# 11   Calumet Beach   2014-05-28T16:00:00               17.1       1.37
# 12  Montrose Beach   2014-05-28T16:00:00               14.4       4.87
# 13   Calumet Beach   2014-05-28T17:00:00               17.2       1.48
# 14  Montrose Beach   2014-05-28T17:00:00               14.1       5.06
# 15  Montrose Beach   2014-05-28T18:00:00               14.2       5.76
# 16   Calumet Beach   2014-05-28T18:00:00               17.1       1.80
# 17   Calumet Beach   2014-05-28T19:00:00               17.0       1.82
# 18  Montrose Beach   2014-05-28T19:00:00               14.2       6.32
#
#     transducer_depth  wave_height  wave_period  battery_life  \
# 10             1.377        0.328          3.0          11.9
# 11             1.520        0.194          4.0          11.7
# 12             1.366        0.341          3.0          11.9
# ...

# %%
duplicated_data = data[data.duplicated()]
duplicated_data.head()
# Out:
# Empty DataFrame
# Columns: [beach_name, measurement_timestamp, water_temperature, turbidity, transducer_depth, wave_height, wave_period, battery_life, measurement_timestamp_label, measurement_id]
# Index: []

# %%
data_aux = data.drop_duplicates()
data_aux.count()
# Out:
# beach_name                     34923
# measurement_timestamp          34917
# water_temperature              34917
# turbidity                      34917
# transducer_depth               10034
# wave_height                    34690
# wave_period                    34690
# battery_life                   34917
# measurement_timestamp_label    34917
# measurement_id                 34923
# dtype: int64

# %%
#que columnas estan repetidas
data_aux = data[0:100].drop_duplicates(subset = ['transducer_depth'])
data_aux.count()
# Out:
# beach_name                     83
# measurement_timestamp          83
# water_temperature              83
# turbidity                      83
# transducer_depth               82
# wave_height                    83
# wave_period                    83
# battery_life                   83
# measurement_timestamp_label    83
# measurement_id                 83
# dtype: int64

# %%
#eliminar
data_aux = data.drop(['timestamp','measurement_timestamp_label',axis = 1])

# %%
data_aux.head()

# %%
data.count()
# Out:
# beach_name                     34923
# measurement_timestamp          34917
# water_temperature              34917
# turbidity                      34917
# transducer_depth               10034
# wave_height                    34690
# wave_period                    34690
# battery_life                   34917
# measurement_timestamp_label    34917
# measurement_id                 34923
# dtype: int64

# %%
#eliminar nulls
data_aux = data.dropna()
data_aux.count()
# Out:
# beach_name                     10034
# measurement_timestamp          10034
# water_temperature              10034
# turbidity                      10034
# transducer_depth               10034
# wave_height                    10034
# wave_period                    10034
# battery_life                   10034
# measurement_timestamp_label    10034
# measurement_id                 10034
# dtype: int64

# %%
#hacer copias del dataset
data2= data.copy(deep = True)
data3= data.copy(deep = False)

# %%
data.head()
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28T12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0             0.891        0.080          3.0           9.4
# 1               NaN        0.111          4.0          12.4
# 2             1.201        0.174          6.0           9.4
# 3             1.514        0.147          4.0          11.7
# 4             1.388        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id
# 0         2013-08-30T08:00:00    MontroseBeach201308300800
# ...

# %%
#con cual queda enlazada,rellenar datos nulls con el promedio
mean_depth = data['transducer_depth'].mean()
print(mean_depth )
data['transducer_depth'].fillna(value = mean_depth, inplace = True)
data.head()
# Out:
# 1.570235000996614
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28T12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0          0.891000        0.080          3.0           9.4
# 1          1.570235        0.111          4.0          12.4
# 2          1.201000        0.174          6.0           9.4
# 3          1.514000        0.147          4.0          11.7
# 4          1.388000        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id
# 0         2013-08-30T08:00:00    MontroseBeach201308300800
# ...

# %%
data.head()
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28T12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0          0.891000        0.080          3.0           9.4
# 1          1.570235        0.111          4.0          12.4
# 2          1.201000        0.174          6.0           9.4
# 3          1.514000        0.147          4.0          11.7
# 4          1.388000        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id
# 0         2013-08-30T08:00:00    MontroseBeach201308300800
# ...

# %%
colours = ['#000099','#ffff00']
sns.heatmap(data.isnull(),cmap=sns.color_palette(colours))
plt.show()

# %%
#promedio de varias columnas,lista de medias de cada columna
mean_vals = data [['turbidity']].mean()
mean_vals

# %%
#todos los valores nulls los complete con esos datos 
data [['turbidity']]=data[['turbidity']].fillna(value=mean_vals)

# %%
data.isnull().sum()
# Out:
# beach_name                       0
# measurement_timestamp            6
# water_temperature                6
# turbidity                        0
# transducer_depth                 0
# wave_height                    233
# wave_period                    233
# battery_life                     6
# measurement_timestamp_label      6
# measurement_id                   0
# dtype: int64

# %%
#rellenar con valores adyacentes
data_transducer_depth = data2.transducer_depth.fillna(method = 'bfill')# propagasion hacia adelante,propagacion asia atras 'bfill'
data.head()
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28T12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0          0.891000        0.080          3.0           9.4
# 1          1.570235        0.111          4.0          12.4
# 2          1.201000        0.174          6.0           9.4
# 3          1.514000        0.147          4.0          11.7
# 4          1.388000        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id
# 0         2013-08-30T08:00:00    MontroseBeach201308300800
# ...

# %%
#agrupar las filas con un campo comun
data[data['beach_name']=='Calumet Beach'].head()
# Out:
#       beach_name measurement_timestamp  water_temperature  turbidity  \
# 2  Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3  Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 6  Calumet Beach   2014-05-28T13:00:00               16.3       1.28
# 8  Calumet Beach   2014-05-28T14:00:00               16.5       1.32
# 9  Calumet Beach   2014-05-28T15:00:00               16.8       1.31
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 2             1.201        0.174          6.0           9.4
# 3             1.514        0.147          4.0          11.7
# 6             1.524        0.162          4.0          11.7
# 8             1.537        0.185          4.0          11.7
# 9             1.568        0.196          4.0          11.7
#
#   measurement_timestamp_label            measurement_id
# 2         2013-09-03T16:00:00  CalumetBeach201309031600
# 3         2014-05-28T12:00:00  CalumetBeach201405281200
# ...

# %%
#Agrergar columnas procesadas,agregar serie
data['HDepth']=data['transducer_depth']<1
data.head()
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26T13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03T16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28T12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28T12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0          0.891000        0.080          3.0           9.4
# 1          1.570235        0.111          4.0          12.4
# 2          1.201000        0.174          6.0           9.4
# 3          1.514000        0.147          4.0          11.7
# 4          1.388000        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id  HDepth
# 0         2013-08-30T08:00:00    MontroseBeach201308300800    True
# ...

# %%
#eliminar
data= data.drop(labels = 'HDepth', axis=1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-0f72bd046b5d> in <module>
#       1 #eliminar
# ----> 2 data= data.drop(labels = 'HDepth', axis=1)
#       3 data.head()
#
# ~\anaconda3\envs\entornomp1\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# ~\anaconda3\envs\entornomp1\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
#Estampa de tiempo ,formato año .mes,min,
data['measurement_timestamp'] = pd.to_datetime(data['measurement_timestamp'], format = '%Y-%m-%dT%H:%M:%S')
data.head()
# Out:
#           beach_name measurement_timestamp  water_temperature  turbidity  \
# 0     Montrose Beach   2013-08-30 08:00:00               20.3       1.18
# 1  Ohio Street Beach   2016-05-26 13:00:00               14.4       1.23
# 2      Calumet Beach   2013-09-03 16:00:00               23.2       3.63
# 3      Calumet Beach   2014-05-28 12:00:00               16.2       1.26
# 4     Montrose Beach   2014-05-28 12:00:00               14.4       3.36
#
#    transducer_depth  wave_height  wave_period  battery_life  \
# 0          0.891000        0.080          3.0           9.4
# 1          1.570235        0.111          4.0          12.4
# 2          1.201000        0.174          6.0           9.4
# 3          1.514000        0.147          4.0          11.7
# 4          1.388000        0.298          4.0          11.9
#
#   measurement_timestamp_label               measurement_id  HDepth
# 0         2013-08-30T08:00:00    MontroseBeach201308300800    True
# ...

# %%
#ordenar los datos,organizarlos por fecha
data_aux = data.sort_values(by='measurement_timestamp')
data_aux.head()
data_aux2 = data_aux[data_aux ['beach_name']=='Montrose Beach']
data_aux2.head()
# Out:
#         beach_name measurement_timestamp  water_temperature  turbidity  \
# 0   Montrose Beach   2013-08-30T08:00:00               20.3       1.18
# 4   Montrose Beach   2014-05-28T12:00:00               14.4       3.36
# 5   Montrose Beach   2014-05-28T13:00:00               14.5       2.72
# 7   Montrose Beach   2014-05-28T14:00:00               14.8       2.97
# 10  Montrose Beach   2014-05-28T15:00:00               14.5       4.30
#
#     transducer_depth  wave_height  wave_period  battery_life  \
# 0              0.891        0.080          3.0           9.4
# 4              1.388        0.298          4.0          11.9
# 5              1.395        0.306          3.0          11.9
# 7              1.386        0.328          3.0          11.9
# 10             1.377        0.328          3.0          11.9
#
#    measurement_timestamp_label             measurement_id  HDepth
# 0          2013-08-30T08:00:00  MontroseBeach201308300800    True
# ...

# %%
#diagrama de caja
sns.boxplot(data = data[['water_temperature']])
# Out:
# <AxesSubplot:>

# %%
from sicpy import stats
Zscore = np.abs(stats.zscore(data.loc[:,['water_temperature','turbidity']]))

index,flag = np.where(Zscore > 3)
print(index)

# %%
data.loc[index]

# %%
data_out=data[(Zscore < 3).all(axis=1)]
data_out.head()
